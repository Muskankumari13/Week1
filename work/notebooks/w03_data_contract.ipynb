# %% [markdown]
# <a href="https://colab.research.google.com/github/Muskankumari13/Week1/blob/main/work/notebooks/w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# ## Unit of Analysis
#
# One row represents the daily performance of one content item for one client on one report date.
#
# ## Time Window
#
# This notebook analyzes the March 2026 partition of the
# fact_content_daily_performance table.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# ## Features
#
# - gsc_impressions
# - gsc_clicks
# - gsc_avg_position
# - ga4_pageviews
# - ga4_sessions
#
# ## Label
#
# Future content performance (not used as a feature in this notebook).
#
# ## Context
#
# - report_date
# - client_hash_id
# - content_hash_id
#
# ## Excluded
#
# - month (partition field only)
# - client_has_gsc (metadata)
# - client_has_ga4 (metadata)
#
# Excluded because they are context/metadata rather than predictive features.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %% [markdown]
# Grain Verification

# %%
con.sql("""
SELECT
    report_date,
    client_hash_id,
    content_hash_id,
    COUNT(*) AS c
FROM read_parquet(
'hf://datasets/FlyRank/internship-warehouse/fact_content_daily_performance/month=2026-03/data_0.parquet'
)
GROUP BY
    report_date,
    client_hash_id,
    content_hash_id
HAVING COUNT(*) > 1
LIMIT 5;
""").df()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Empty DataFrame
# Columns: [report_date, client_hash_id, content_hash_id, c]
# Index: []

# %% [markdown]
# Row Count + Date Range

# %%
con.sql("""
SELECT
COUNT(*) AS total_rows,
MIN(report_date) AS start_date,
MAX(report_date) AS end_date
FROM read_parquet(
'hf://datasets/FlyRank/internship-warehouse/fact_content_daily_performance/month=2026-03/data_0.parquet'
);
""").df()
# Out:
#    total_rows start_date   end_date
# 0     9841378 2026-03-01 2026-03-31

# %% [markdown]
# Availability Check (IS TRUE)

# %%
con.sql("""
SELECT
COUNT(*) AS available_rows
FROM read_parquet(
'hf://datasets/FlyRank/internship-warehouse/fact_content_daily_performance/month=2026-03/data_0.parquet'
)
WHERE ga4_data_available IS TRUE;
""").df()
# Out:
#    available_rows
# 0          413966

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# ## Data Limits
#
# - Different clients have different history lengths.
# - Early rows may not contain GA4 data.
# - This notebook uses only one month (March 2026).
# - Results should be treated as decision support rather than causal conclusions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
# ✅ Every section completed
#
# ✅ Notebook runs successfully
#
# ✅ No private information included
#
# ✅ Careful wording used
#
# ✅ Saved under work/notebooks
